# %% [markdown]
# Plot for sentiment analysis

# %%
#For SST:
sst_train_loss = [1.534, 1.285, 1.082, 0.873, 0.671, 0.498, 0.386, 0.289, 0.228, 0.180]
sst_train_acc = [0.422, 0.563, 0.704, 0.761, 0.817, 0.881, 0.923, 0.934, 0.949, 0.958]
sst_dev_acc = [0.368, 0.410, 0.399, 0.386, 0.375, 0.353, 0.367, 0.365, 0.339, 0.360]

# For CFIMDB:
cfimdb_train_loss = [0.663, 0.390, 0.233, 0.121, 0.073, 0.070, 0.014, 0.032, 0.020, 0.003]
cfimdb_train_acc = [0.844, 0.934, 0.965, 0.988, 0.990, 0.995, 1.000, 0.999, 1.000, 0.999]
cfimdb_dev_acc = [0.808, 0.837, 0.845, 0.853, 0.849, 0.849, 0.849, 0.837, 0.841, 0.845]

# %%
print(max(sst_dev_acc))
# Out:
# 0.41

# %%
import matplotlib.pyplot as plt

epochs = range(1, 11)

# Plot for SST
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, sst_train_loss, marker='o', label='Train Loss')
plt.plot(epochs, sst_train_acc, marker='o', label='Train Accuracy')
plt.plot(epochs, sst_dev_acc, marker='o', label='Dev Accuracy')
plt.title('SST Training Results')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

# Plot for CFIMDB
plt.subplot(1, 2, 2)
plt.plot(epochs, cfimdb_train_loss, marker='o', label='Train Loss')
plt.plot(epochs, cfimdb_train_acc, marker='o', label='Train Accuracy')
plt.plot(epochs, cfimdb_dev_acc, marker='o', label='Dev Accuracy')
plt.title('CFIMDB Training Results')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# After change config

# %%
# Plot the extracted training results

import matplotlib.pyplot as plt
# SST
sst_train_loss = [1.35, 1.067, 0.853, 0.647, 0.439, 0.294, 0.205, 0.141, 0.123, 0.108]
sst_train_acc = [0.573, 0.67, 0.786, 0.85, 0.943, 0.958, 0.977, 0.987, 0.966, 0.991]
sst_dev_acc = [0.48, 0.504, 0.49, 0.451, 0.472, 0.471, 0.45, 0.468, 0.46, 0.456]

# CFIMDB
cfimdb_train_loss = [0.338, 0.104, 0.087, 0.038, 0.055, 0.043, 0.025, 0.004, 0.0, 0.011]
cfimdb_train_acc = [0.975, 0.985, 0.992, 0.981, 0.996, 0.996, 0.999, 1.0, 1.0, 0.99]
cfimdb_dev_acc = [0.943, 0.943, 0.939, 0.902, 0.959, 0.967, 0.955, 0.967, 0.967, 0.927]


epochs = range(1, 11)

# Plot for SST
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, sst_train_loss, marker='o', label='Train Loss')
plt.plot(epochs, sst_train_acc, marker='o', label='Train Accuracy')
plt.plot(epochs, sst_dev_acc, marker='o', label='Dev Accuracy')
plt.title('SST Training Results')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

# Plot for CFIMDB
plt.subplot(1, 2, 2)
plt.plot(epochs, cfimdb_train_loss, marker='o', label='Train Loss')
plt.plot(epochs, cfimdb_train_acc, marker='o', label='Train Accuracy')
plt.plot(epochs, cfimdb_dev_acc, marker='o', label='Dev Accuracy')
plt.title('CFIMDB Training Results')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
